# %%
import pandas as pd

# Load the first CSV file into a DataFrame
df1 = pd.read_csv(r'C:\Users\a21ma\OneDrive\Desktop\Datahack\DataHack_2_Tensionflow\feature_df.csv')  # Change to the path of your first CSV file

# Load the second CSV file into another DataFrame
df2 = pd.read_csv(r'C:\Users\a21ma\OneDrive\Desktop\Datahack\DataHack_2_Tensionflow\Gender_Data.csv')  # Change to the path of your second CSV file

# Choose the column of interest in both DataFrames
column_to_check = 'Column_Name'  # Replace 'Column_Name' with the actual column name

# Check if all entries in the first column are present in the second column
# are_all_present = df1['Lawyer Names'].isin(df2['Name']).all()

# if are_all_present:
#     print(f'All entries in {column_to_check} from file1 are in file2.')
# else:
#     print(f'Some entries in {column_to_check} from file1 are not in file2.')

df1['First_Name'] = df1['Lawyer Names'].str.split().str[0]

entries_not_in_df2 = df1[~df1['First_Name'].isin(df2['Name'])]

# Display the entries that are not in df2
print("Entries not in df2:")
entries_not_in_df2
# Out:
# Entries not in df2:
#            Lawyer Names                                                  0  \
# 6          Rania Bansal  Rania Bansal has 21 years of experience in Lab...
# 13    Vardaniya Mallick  Vardaniya Mallick has 24 years of experience i...
# 17         Aaryahi Sood  Aaryahi Sood has 24 years of experience in Con...
# 18          Suhana Bawa  Suhana Bawa has 3 years of experience in Human...
# 19           Anahi Gala  Anahi Gala has 22 years of experience in Labor...
# ...                 ...                                                ...
# 1974        Abram Sagar  Abram Sagar has 17 years of experience in Cons...
# 1978      Neelofar Virk  Neelofar Virk has 6 years of experience in Med...
# 1982      Shayak Chawla  Shayak Chawla has 15 years of experience in Fa...
# 1986         Dhanuk Roy  Dhanuk Roy has 3 years of experience in Intell...
# 1990        Rania Sinha  Rania Sinha has 29 years of experience in Medi...
#
# ...

# %%
df_no_duplicates = entries_not_in_df2.drop_duplicates(subset='First_Name')
df_no_duplicates = df_no_duplicates['First_Name']

# %%
df3 = pd.read_csv(r'C:\Users\a21ma\OneDrive\Desktop\Datahack\DataHack_2_Tensionflow\GendersNotInDataset.csv')

# %%
merged_df = entries_not_in_df2.merge(df3, on='First_Name', how='inner')
merged_df.drop(['Unnamed: 0'], axis=1, inplace=True)
merged_df.drop(['Unnamed: 0.1'], axis=1, inplace=True)
merged_df
# Out:
#         Lawyer Names                                                  0  \
# 0       Rania Bansal  Rania Bansal has 21 years of experience in Lab...
# 1    Rania Deshpande  Rania Deshpande has 18 years of experience in ...
# 2        Rania Salvi  Rania Salvi has 24 years of experience in Labo...
# 3       Rania Sahota  Rania Sahota has 8 years of experience in Tax ...
# 4        Rania Bhatt  Rania Bhatt has 29 years of experience in Tax ...
# ..               ...                                                ...
# 271        Ryan Vala  Ryan Vala has 7 years of experience in Immigra...
# 272      Taimur Gour  Taimur Gour has 9 years of experience in Const...
# 273      Taimur Shah  Taimur Shah has 5 years of experience in Corpo...
# 274     Taimur Lalla  Taimur Lalla has 5 years of experience in Tax ...
# 275     Taimur Krish  Taimur Krish has 5 years of experience in Crim...
#
#                                               1  \
# 0    He has a Client Feedback of 4.0 out of 5.0
# ...

# %%
merged_df.to_csv(r'C:\Users\a21ma\OneDrive\Desktop\Datahack\DataHack_2_Tensionflow\merged_df2.csv')

# %%
# df_no_duplicates.to_csv(r"C:\Users\a21ma\OneDrive\Desktop\Datahack\DataHack_2_Tensionflow\no_duplicates.csv")

# %%
# entries_not_in_df2.to_csv(r"C:\Users\a21ma\OneDrive\Desktop\Datahack\DataHack_2_Tensionflow\names_not_in_dataset.csv")
