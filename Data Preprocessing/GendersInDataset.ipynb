# %%
import pandas as pd

# Load the first CSV file into a DataFrame
df1 = pd.read_csv(r'C:\Users\a21ma\OneDrive\Desktop\Datahack\DataHack_2_Tensionflow\feature_df.csv')  # Change to the path of your first CSV file

# Load the second CSV file into another DataFrame
df2 = pd.read_csv(r'C:\Users\a21ma\OneDrive\Desktop\Datahack\DataHack_2_Tensionflow\Gender_Data.csv')  # Change to the path of your second CSV file

# %%
df2 = df2.rename(columns={'Name': 'First_Name'})
df2
# Out:
#       First_Name  Gender
# 0          Aaban       0
# 1       Aabharan       0
# 2         Aabhas       0
# 3         Aabhat       0
# 4        Aabheer       0
# ...          ...     ...
# 53977    Zumathy       1
# 53978     Zurika       1
# 53979    Zuruthi       1
# 53980  Zuruthika       1
# 53981     Zuvaka       1
#
# [53982 rows x 2 columns]

# %%
# df1['9'] =

# %%
df1['First_Name'] = df1['Lawyer Names'].str.split().str[0]

# %%
df1
# Out:
#           Lawyer Names                                                  0  \
# 0       Anay Ahluwalia  Anay Ahluwalia has 20 years of experience in C...
# 1          Arnav Dubey  Arnav Dubey has 29 years of experience in Inte...
# 2        Lavanya Lalla  Lavanya Lalla has 15 years of experience in Hu...
# 3        Armaan Khosla  Armaan Khosla has 11 years of experience in Co...
# 4        Advik Chaudry  Advik Chaudry has 8 years of experience in Hum...
# ...                ...                                                ...
# 1994     Amani Mallick  Amani Mallick has 18 years of experience in En...
# 1995         Zoya Shan  Zoya Shan has 18 years of experience in Family...
# 1996       Ayesha Dani  Ayesha Dani has 17 years of experience in Envi...
# 1997       Zaina Soman  Zaina Soman has 24 years of experience in Cons...
# 1998  Dhanush Krishnan  Dhanush Krishnan has 3 years of experience in ...
#
#                                                1  \
# ...

# %%
common_entries = df1['First_Name'].isin(df2['Name'])
common_entries_df = df1[common_entries]
# common_entries_df = common_entries_df['First_Name'].drop_duplicates()
common_entries_df
# Out:
#           Lawyer Names                                                  0  \
# 0       Anay Ahluwalia  Anay Ahluwalia has 20 years of experience in C...
# 1          Arnav Dubey  Arnav Dubey has 29 years of experience in Inte...
# 2        Lavanya Lalla  Lavanya Lalla has 15 years of experience in Hu...
# 3        Armaan Khosla  Armaan Khosla has 11 years of experience in Co...
# 4        Advik Chaudry  Advik Chaudry has 8 years of experience in Hum...
# ...                ...                                                ...
# 1994     Amani Mallick  Amani Mallick has 18 years of experience in En...
# 1995         Zoya Shan  Zoya Shan has 18 years of experience in Family...
# 1996       Ayesha Dani  Ayesha Dani has 17 years of experience in Envi...
# 1997       Zaina Soman  Zaina Soman has 24 years of experience in Cons...
# 1998  Dhanush Krishnan  Dhanush Krishnan has 3 years of experience in ...
#
#                                                1  \
# ...

# %%
merged_df = common_entries_df.merge(df2, on='First_Name', how='inner')
merged_df
# Out:
#         Lawyer Names                                                  0  \
# 0     Anay Ahluwalia  Anay Ahluwalia has 20 years of experience in C...
# 1           Anay Kar  Anay Kar has 17 years of experience in Banking...
# 2         Anay Batra  Anay Batra has 20 years of experience in Civil...
# 3         Anay Bajaj  Anay Bajaj has 13 years of experience in Media...
# 4         Anay Wagle  Anay Wagle has 7 years of experience in Tax La...
# ...              ...                                                ...
# 1728   Shray Sampath  Shray Sampath has 24 years of experience in Ba...
# 1729     Shray Devan  Shray Devan has 23 years of experience in Labo...
# 1730     Sara Thaker  Sara Thaker has 15 years of experience in Immi...
# 1731       Sara Kant  Sara Kant has 2 years of experience in Tax Law...
# 1732       Sara Sami  Sara Sami has 3 years of experience in Labor L...
#
#                                                1  \
# 0     He has a Client Feedback of 5.0 out of 5.0
# ...

# %%
merged_df['Gender'] = merged_df['Gender'].replace({1: 'Female', 0: 'Male'})
merged_df
# Out:
#         Lawyer Names                                                  0  \
# 0     Anay Ahluwalia  Anay Ahluwalia has 20 years of experience in C...
# 1           Anay Kar  Anay Kar has 17 years of experience in Banking...
# 2         Anay Batra  Anay Batra has 20 years of experience in Civil...
# 3         Anay Bajaj  Anay Bajaj has 13 years of experience in Media...
# 4         Anay Wagle  Anay Wagle has 7 years of experience in Tax La...
# ...              ...                                                ...
# 1728   Shray Sampath  Shray Sampath has 24 years of experience in Ba...
# 1729     Shray Devan  Shray Devan has 23 years of experience in Labo...
# 1730     Sara Thaker  Sara Thaker has 15 years of experience in Immi...
# 1731       Sara Kant  Sara Kant has 2 years of experience in Tax Law...
# 1732       Sara Sami  Sara Sami has 3 years of experience in Labor L...
#
#                                                1  \
# 0     He has a Client Feedback of 5.0 out of 5.0
# ...

# %%
merged_df.to_csv(r'C:\Users\a21ma\OneDrive\Desktop\Datahack\DataHack_2_Tensionflow\merged_df.csv')
