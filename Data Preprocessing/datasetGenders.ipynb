# %%
import pandas as pd

# %%
df1 = pd.read_csv('merged_df.csv')
df2 = pd.read_csv('merged_df2.csv')

# %%
df = pd.concat([df1, df2], ignore_index=True)
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.sort_values(by='Lawyer Names', inplace=True, ignore_index=True)
df.drop(['First_Name'], axis=1, inplace=True)
df
# Out:
#           Lawyer Names                                                  0  \
# 0        Aaina Ganesan  Aaina Ganesan has 21 years of experience in Co...
# 1          Aaina Gopal  Aaina Gopal has 15 years of experience in Huma...
# 2          Aaina Kanda  Aaina Kanda has 22 years of experience in Medi...
# 3           Aaina Kaul  Aaina Kaul has 5 years of experience in Consum...
# 4         Aaina Kurian  Aaina Kurian has 7 years of experience in Corp...
# ...                ...                                                ...
# 2004         Zoya Shan  Zoya Shan has 18 years of experience in Family...
# 2005         Zoya Sood  Zoya Sood has 7 years of experience in Immigra...
# 2006  Zoya Subramaniam  Zoya Subramaniam has 10 years of experience in...
# 2007        Zoya Verma  Zoya Verma has 15 years of experience in Intel...
# 2008         Zoya Wali  Zoya Wali has 29 years of experience in Real E...
#
#                                                1  \
# ...

# %%
# df.to_csv('merged_df3.csv')

# %%
df.drop_duplicates(subset=['Lawyer Names'], inplace=True, ignore_index=True)
df
# Out:
#           Lawyer Names                                                  0  \
# 0        Aaina Ganesan  Aaina Ganesan has 21 years of experience in Co...
# 1          Aaina Gopal  Aaina Gopal has 15 years of experience in Huma...
# 2          Aaina Kanda  Aaina Kanda has 22 years of experience in Medi...
# 3           Aaina Kaul  Aaina Kaul has 5 years of experience in Consum...
# 4         Aaina Kurian  Aaina Kurian has 7 years of experience in Corp...
# ...                ...                                                ...
# 1994         Zoya Shan  Zoya Shan has 18 years of experience in Family...
# 1995         Zoya Sood  Zoya Sood has 7 years of experience in Immigra...
# 1996  Zoya Subramaniam  Zoya Subramaniam has 10 years of experience in...
# 1997        Zoya Verma  Zoya Verma has 15 years of experience in Intel...
# 1998         Zoya Wali  Zoya Wali has 29 years of experience in Real E...
#
#                                                1  \
# ...

# %%
df['Gender'] = df['Gender'].replace({'female': 'Female', 'male': 'Male'})
df
# Out:
#           Lawyer Names                                                  0  \
# 0        Aaina Ganesan  Aaina Ganesan has 21 years of experience in Co...
# 1          Aaina Gopal  Aaina Gopal has 15 years of experience in Huma...
# 2          Aaina Kanda  Aaina Kanda has 22 years of experience in Medi...
# 3           Aaina Kaul  Aaina Kaul has 5 years of experience in Consum...
# 4         Aaina Kurian  Aaina Kurian has 7 years of experience in Corp...
# ...                ...                                                ...
# 1994         Zoya Shan  Zoya Shan has 18 years of experience in Family...
# 1995         Zoya Sood  Zoya Sood has 7 years of experience in Immigra...
# 1996  Zoya Subramaniam  Zoya Subramaniam has 10 years of experience in...
# 1997        Zoya Verma  Zoya Verma has 15 years of experience in Intel...
# 1998         Zoya Wali  Zoya Wali has 29 years of experience in Real E...
#
#                                                1  \
# ...

# %%
df.to_csv('final.csv')
