# %%
import pandas as pd

# %%
df1 = pd.read_csv('Post_Regex_Data.csv')
df2 = pd.read_csv('final.csv')

# %%
df1.sort_values(by='Lawyer Names', inplace=True, ignore_index=True)
df1
# Out:
#       Rating       Jurisdiction  Charges  Days_of_disposal           City  \
# 0        5.0      Supreme Court      489             107.0    ['Chennai']
# 1        4.0     District Court       70              91.0     ['Mumbai']
# 2        4.0     District Court      282             106.0     ['Mumbai']
# 3        1.0  Specialized Court      490             102.0     ['Mumbai']
# 4        1.0  Specialized Court      441              85.0  ['Hyderabad']
# ...      ...                ...      ...               ...            ...
# 1994     2.0  Specialized Court       81              94.0    ['Chennai']
# 1995     4.0         High Court      440             103.0  ['Hyderabad']
# 1996     1.0  Specialized Court      464             107.0  ['Bangalore']
# 1997     3.0      Supreme Court      427              85.0    ['Chennai']
# 1998     3.0  Specialized Court      495             101.0      ['Delhi']
#
#       Years_of_Experience                                     Type_of_Lawyer  \
# ...

# %%
df1['Gender'] = df2['Gender']
df1
# Out:
#       Rating       Jurisdiction  Charges  Days_of_disposal           City  \
# 0        5.0      Supreme Court      489             107.0    ['Chennai']
# 1        4.0     District Court       70              91.0     ['Mumbai']
# 2        4.0     District Court      282             106.0     ['Mumbai']
# 3        1.0  Specialized Court      490             102.0     ['Mumbai']
# 4        1.0  Specialized Court      441              85.0  ['Hyderabad']
# ...      ...                ...      ...               ...            ...
# 1994     2.0  Specialized Court       81              94.0    ['Chennai']
# 1995     4.0         High Court      440             103.0  ['Hyderabad']
# 1996     1.0  Specialized Court      464             107.0  ['Bangalore']
# 1997     3.0      Supreme Court      427              85.0    ['Chennai']
# 1998     3.0  Specialized Court      495             101.0      ['Delhi']
#
#       Years_of_Experience                                     Type_of_Lawyer  \
# ...

# %%
df1.to_csv('FINALdataset.csv')
